# %%
from shining_pebbles import scan_files_including_regex, open_json_in_file_folder_by_regex

# %%
DIR_LOG = r'C:\MyNewProject\OpenManus\results'
DIR_LOG
# Out:
# 'C:\\MyNewProject\\OpenManus\\results'

# %%
file_names = scan_files_including_regex(file_folder=DIR_LOG, regex='JSON-005930')
file_names
# Out:
# ['JSON-005930-삼성전자-20250604_164156-save20250604_164156.json',
#  'JSON-005930-삼성전자-20250610_090519-save20250610_090519.json']

# %%
dct = open_json_in_file_folder_by_regex(file_folder=DIR_LOG, regex='042660')
dct
# Out:
# {'한화오션에 대해서 분석해줘': "\n=== 종목 분류 결과 ===\n🏷️ 분류: 시이클주\n📊 신뢰도: 높음\n📋 근거: - 매출 성장률 <5%: 조선업의 특성상 프로젝트에 따라 매출 변동이 크므로, 저성장주로 보기 어려움., - 점수: 2점, - 대기업, 안정적 실적, 꾸준한 배당, 업계 리더: 한화오션은 대형 조선사이지만, 조선업의 특성상 실적 변동성이 큼.\n\n--- 상세 분석은 아래를 확인하세요 ---\n\n\n=== 종목 분류 상세 분석 ===\n📊 **분류 결과:** 시이클주\n🎯 **신뢰도:** 높음\n\n📋 **분류 근거:**\n1. - 매출 성장률 <5%: 조선업의 특성상 프로젝트에 따라 매출 변동이 크므로, 저성장주로 보기 어려움.\n2. - 점수: 2점\n3. - 대기업, 안정적 실적, 꾸준한 배당, 업계 리더: 한화오션은 대형 조선사이지만, 조선업의 특성상 실적 변동성이 큼.\n4. - 점수: 3점\n5. - 매출 성장률 >15%, 혁신기술, 높은 성장잠재력: 조선업은 전통 산업으로 고성장주로 보기 어려움.\n6. - 점수: 1점\n7. - PBR <1, 자산가치 높음, 부동산/보유자산 중요: 조선업체들은 자산 대비 주가가 낮은 경우가 많음.\n8. - 점수: 3점\n9. - 현재 부진하지만 실적개선 예상, 구조조정 중: 조선업체들은 경기 회복 시 실적 개선 가능성이 있음.\n10. - 점수: 4점\n11. - 경기변동 민감, 원자재/에너지/화학 등: 조선업은 경기 변동에 매우 민감함.\n12. - 점수: 5점\n13. - 위 분류에 명확히 해당하지 않는 특수한 경우: 조선업은 명확히 시이클주에 해당.\n14. - 점수: 1점\n15. **최종 분류: 시이클주 (Cyclical Stock)**\n16. **근거:**\n17. - 한화오션은 조선업에 속하며, 글로벌 경기와 해운업의 수요에 따라 실적이 크게 변동하는 특성을 가지고 있습니다. 이는 시이클주의 전형적인 특징에 부합합니다.\n18. **신뢰도 평가: 높음**\n19. - 
# ...

# %%
# Out:
# "\n=== 종목 분류 결과 ===\n🏷️ 분류: 시이클주\n📊 신뢰도: 높음\n📋 근거: - 매출 성장률 <5%: 조선업의 특성상 프로젝트에 따라 매출 변동이 크므로, 저성장주로 보기 어려움., - 점수: 2점, - 대기업, 안정적 실적, 꾸준한 배당, 업계 리더: 한화오션은 대형 조선사이지만, 조선업의 특성상 실적 변동성이 큼.\n\n--- 상세 분석은 아래를 확인하세요 ---\n\n\n=== 종목 분류 상세 분석 ===\n📊 **분류 결과:** 시이클주\n🎯 **신뢰도:** 높음\n\n📋 **분류 근거:**\n1. - 매출 성장률 <5%: 조선업의 특성상 프로젝트에 따라 매출 변동이 크므로, 저성장주로 보기 어려움.\n2. - 점수: 2점\n3. - 대기업, 안정적 실적, 꾸준한 배당, 업계 리더: 한화오션은 대형 조선사이지만, 조선업의 특성상 실적 변동성이 큼.\n4. - 점수: 3점\n5. - 매출 성장률 >15%, 혁신기술, 높은 성장잠재력: 조선업은 전통 산업으로 고성장주로 보기 어려움.\n6. - 점수: 1점\n7. - PBR <1, 자산가치 높음, 부동산/보유자산 중요: 조선업체들은 자산 대비 주가가 낮은 경우가 많음.\n8. - 점수: 3점\n9. - 현재 부진하지만 실적개선 예상, 구조조정 중: 조선업체들은 경기 회복 시 실적 개선 가능성이 있음.\n10. - 점수: 4점\n11. - 경기변동 민감, 원자재/에너지/화학 등: 조선업은 경기 변동에 매우 민감함.\n12. - 점수: 5점\n13. - 위 분류에 명확히 해당하지 않는 특수한 경우: 조선업은 명확히 시이클주에 해당.\n14. - 점수: 1점\n15. **최종 분류: 시이클주 (Cyclical Stock)**\n16. **근거:**\n17. - 한화오션은 조선업에 속하며, 글로벌 경기와 해운업의 수요에 따라 실적이 크게 변동하는 특성을 가지고 있습니다. 이는 시이클주의 전형적인 특징에 부합합니다.\n18. **신뢰도 평가: 높음**\n19. - 조선업의 특성상 경기 변동에 민감하
# ...

# %%
file_names[0].split('-save')[-1][:8]
# Out:
# '20250604'

# %%
{
    'prompt': '삼성전자에 대해서 분석해줘',
    'response': "\n=== 종목 분류 결과 ===\n🏷️ 분류: 우량주\n📊 신뢰도: 높음\n📋 근거: **삼성전자 분류 분석**, - 매출 성장률 <5%: 2점 (삼성전자는 안정적이지만, 성장률이 5% 미만은 아님), - 안정적이지만 성장성 제한: 2점\n\n--- 상세 분석은 아래를 확인하세요 ---\n\n\n=== 종목 분류 상세 분석 ===\n📊 **분류 결과:** 우량주\n🎯 **신뢰도:** 높음\n\n📋 **분류 근거:**\n1. **삼성전자 분류 분석**\n2. - 매출 성장률 <5%: 2점 (삼성전자는 안정적이지만, 성장률이 5% 미만은 아님)\n3. - 안정적이지만 성장성 제한: 2점\n4. - 총점: 4점\n5. - 대기업: 5점 (한국 최대 시가총액 기업 중 하나)\n6. - 안정적 실적: 5점 (꾸준한 실적과 배당)\n7. - 꾸준한 배당: 5점\n8. - 업계 리더: 5점 (반도체, 모바일 등에서 선도적 위치)\n9. - 총점: 20점\n10. - 매출 성장률 >15%: 2점 (성장률이 높지만 15% 이상은 아님)\n11. - 혁신기술: 4점 (반도체, 모바일 등에서 혁신적 기술 보유)\n12. - 높은 성장 잠재력: 4점\n13. - 총점: 10점\n14. - PBR <1: 2점 (PBR이 1~2 사이)\n15. - 자산가치 높음: 3점\n16. - 부동산/보유자산 중요: 2점\n17. - 총점: 7점\n18. - 현재 부진하지만 실적 개선 예상: 1점 (현재 부진하지 않음)\n19. - 구조조정 중: 1점\n20. - 총점: 2점\n21. - 경기변동 민감: 3점 (반도체 업황에 민감하지만 전반적으로 안정적)\n22. - 원자재/에너지/화학 등: 2점\n23. - 총점: 5점\n24. - 위 분류에 명확히 해당하지 않는 특수한 경우: 1점\n25. - 총점: 1점\n26. **최종 분류: 우량주 (Blue Chip Stock)**\n27. - **근거**: 삼성전자는 대기업으로서 안정적인 실적과 꾸준한 배당을 제공하며, 반도체 및 모바일 등 다양한 사업 영역에서 업계 리더로 자리 잡고 있습니다. 시가총액이 크고, 글로벌 시장에서의 영향력도 큽니다.\n28. - **신뢰도 평가**: 높음 (삼성전자는 명확히 우량주로 분류될 수 있는 특성을 다수 보유하고 있습니다.)\n\n💡 **AI 분석 전문:**\nStep 1: 종목 기본 정보 분석을 완료했습니다.\n\n삼성전자에 대한 기본 정보를 다음과 같이 정리할 수 있습니다:\n\n1. **종목명 및 종목코드**\n   - 종목명: 삼성전자\n   - 종목코드: 005930 (KOSPI)\n\n2. **업종 분류**\n   - 전자 및 전기기기 제조업\n\n3. **시가총액 규모**\n   - 삼성전자는 한국 증시에서 가장 큰 시가총액을 보유한 기업 중 하나로, 시가총액은 수백조 원에 달합니다.\n\n4. **주요 사업 영역**\n   - 반도체: 메모리 반도체, 시스템 반도체\n   - 디스플레이: OLED, LCD\n   - 모바일: 스마트폰, 태블릿\n   - 가전: TV, 냉장고, 세탁기 등\n   - 네트워크: 5G 네트워크 장비\n\n5. **최근 3년간 매출 및 영업이익 추이**\n   - 삼성전자는 매출과 영업이익에서 꾸준한 성장을 보여왔습니다. 다만, 반도체 업황에 따라 실적 변동이 있을 수 있습니다.\n   - 예시: 2020년, 2021년, 2022년 각각의 매출과 영업이익은 수십조 원대에 이르며, 매출 성장률은 대체로 안정적입니다.\n\n6. **주요 재무지표**\n   - PER: 대체로 10~20 사이\n   - PBR: 1~2 사이\n   - ROE: 10% 이상\n   - 부채비율: 50% 이하로 안정적\n\n위 정보를 바탕으로 삼성전자는 **우량주 (Blue Chip Stock)**로 분류할 수 있습니다. 삼성전자는 시가총액이 크고, 다양한 사업 영역에서 업계 선도적인 위치를 차지하고 있으며, 안정적인 실적과 배당을 제공하는 기업입니다.\nStep 2: 종목 분류를 완료했습니다.\n\n**삼성전자 분류 분석**\n\n1. **저성장주**\n   - 매출 성장률 <5%: 2점 (삼성전자는 안정적이지만, 성장률이 5% 미만은 아님)\n   - 안정적이지만 성장성 제한: 2점\n   - 총점: 4점\n\n2. **우량주**\n   - 대기업: 5점 (한국 최대 시가총액 기업 중 하나)\n   - 안정적 실적: 5점 (꾸준한 실적과 배당)\n   - 꾸준한 배당: 5점\n   - 업계 리더: 5점 (반도체, 모바일 등에서 선도적 위치)\n   - 총점: 20점\n\n3. **고성장주**\n   - 매출 성장률 >15%: 2점 (성장률이 높지만 15% 이상은 아님)\n   - 혁신기술: 4점 (반도체, 모바일 등에서 혁신적 기술 보유)\n   - 높은 성장 잠재력: 4점\n   - 총점: 10점\n\n4. **자산주**\n   - PBR <1: 2점 (PBR이 1~2 사이)\n   - 자산가치 높음: 3점\n   - 부동산/보유자산 중요: 2점\n   - 총점: 7점\n\n5. **턴어라운드주**\n   - 현재 부진하지만 실적 개선 예상: 1점 (현재 부진하지 않음)\n   - 구조조정 중: 1점\n   - 총점: 2점\n\n6. **시이클주**\n   - 경기변동 민감: 3점 (반도체 업황에 민감하지만 전반적으로 안정적)\n   - 원자재/에너지/화학 등: 2점\n   - 총점: 5점\n\n7. **기타주**\n   - 위 분류에 명확히 해당하지 않는 특수한 경우: 1점\n   - 총점: 1점\n\n**최종 분류: 우량주 (Blue Chip Stock)**\n\n- **근거**: 삼성전자는 대기업으로서 안정적인 실적과 꾸준한 배당을 제공하며, 반도체 및 모바일 등 다양한 사업 영역에서 업계 리더로 자리 잡고 있습니다. 시가총액이 크고, 글로벌 시장에서의 영향력도 큽니다.\n\n- **신뢰도 평가**: 높음 (삼성전자는 명확히 우량주로 분류될 수 있는 특성을 다수 보유하고 있습니다.)\nStep 3: === 종목 분류 결과 ===\n🏷️ **분류: 우량주 (Blue Chip Stock)**\n📊 **신뢰도: 높음**\n📋 **주요 근거:**\n• 삼성전자는 한국 최대 시가총액 기업 중 하나로, 대기업입니다.\n• 안정적인 실적과 꾸준한 배당을 제공하고 있습니다.\n• 반도체, 모바일 등 다양한 사업 영역에서 업계 리더로 자리 잡고 있습니다.\n\n🔍 **투자 시 고려사항:**\n• 글로벌 경제 상황과 반도체 업황에 따른 실적 변동 가능성\n• 기술 혁신과 시장 경쟁 상황에 대한 지속적인 모니터링 필요\n\n💡 **추가 조언:**\n우량주는 일반적으로 장기 투자에 적합하며, 안정적인 배당 수익을 기대할 수 있습니다. 다만, 시장 변동성에 대비하여 포트폴리오를 다각화하고, 주기적으로 기업의 실적 및 산업 동향을 점검하는 것이 중요합니다.\nTerminated: Reached max steps (3)\n\n🔍 **원시 분석 데이터:**\n입력: 삼성전자에 대해서 분석해줘\n에이전트 상태: IDLE\n\n===============================\n\nStep 1: Observed output of cmd `browser_use` executed:\nSearch results for '삼성전자 주식 분석 2023':\n\n1. 삼성전자(A005930) | Snapshot | 기업정보 | Company Guide - FnGuide\n   URL: https://comp.fnguide.com/SVO2/ASP/SVD_Main.asp?pGB=1&gicode=A005930&cID=&MenuYn=Y&ReportGB=D&NewMenuID=Y&stkGb=701\n   Description:  Financial Highlight ; 매출액. 3,022,314, 2,589,355 ; 영업이익. 433,766, 65,670 ; 영업이익(발표기준). 433,766, 65,670 ; 당기순이익. 556,541, 154,871 ; 지배주주순이익. \n   Content: 삼성전자(A005930) | Snapshot | 기업정보 | Company Guide 본문 바로가기 메뉴 바로가기 상장기업분석 리포트 앱 리타민, 라이트요금제 곧 출시 모든 증권사 리포트를 더 가벼운 요금으로 열기 인쇄 기업정보 Snapshot 기업개요 재무제표 재무비율 투자지표 컨센서스 지분분석 업종분석 경쟁사비교 거래소공시 금감원공시 ETF/ETN 정보 ETF Snapshot 성과 및 위험분석 ETN Snapshot 리포트 리포트동향 요약리포트 실적속보 컨센서스 스크리닝 목표주가 괴리율 컨센서스 상/하향 비율 어닝서프라이즈 턴어라운드 랭킹 분석 업종별 순위 지표별 순위 ETF 순위 캘린더 부가정보 신용등급 기업주소록 이용안내 Retamin Retamin 삼성전자 005930 | 12월 결산 | 홈페이지 홈페이지 http://www.samsung.com 전화번호 전화번호 031-200-1114 | IR 담당자 02-2255-9000 주소 주소 경기도 수원시 영통구 삼성로 129 (매탄동) KSE 코스피 전기·전자 코스피 전기·전자 | FICS 반도체 및 관련장비 | K200 | NXT PER(Price Earning Ratio) 전일자 보통주 수정주가 / 최근 결산 EPS(주당순이익) * EPS = 당기순이익 / 수정평균발행주식수 * 최근결산은 2024/12 (연간) 기준임. PER 12.08 12M PER 전일자 보통주 수정주가 / 12개월 Forward EPS 12M PER 11.63 업종 PER 시장대표업종||SUM(구성종목 시가총액)/SUM(구성종목 당기순이익) * 전일자 보통주 시가총액 기준 * 당기순이익은 최근결산 2024/12 (연간) 기준임. 업종 PER 13.14 PBR(Price Book-value Ratio) 전일자 보통주 수정주가 / 최근 결산기 BPS(주당순자산) * BPS=(지배주주지분-자기주식) / 무상조정기말주식수(우선주 및 자사주 포함) * 최근결산은 2024/12 (연간) 기준임. PBR 1.03 배당수익률 {최근 결산기 보통...\n\nMetadata:\n- Total results: 1\n- Language: en\n- Country: us\nStep 2: Observed output of cmd `browser_use` executed:\nExtracted from page:\n{'text': '삼성전자(A005930) | Snapshot | 기업정보 | Company Guide', 'metadata': {'source': 'Company Guide'}}\n\nStep 3: Here's a summary of the key financial metrics and analysis for 삼성전자 (Samsung Electronics):\n\n### Financial Highlights:\n- **Current Price**: 59,800 KRW\n- **PER (Price Earnings Ratio)**: 12.08\n- **PBR (Price Book-value Ratio)**: 1.03\n- **Dividend Yield**: 2.64%\n\n### Recent Performance:\n- **Revenue**: 3,022,314 million KRW\n- **Operating Profit**: 433,766 million KRW\n- **Net Profit**: 556,541 million KRW\n\n### Investment Ratings:\n- **Consensus Rating**: Buy\n- **Target Price**: 74,000 KRW\n\n### Analysis:\n- Samsung Electronics shows a stable financial position with a reasonable PER and PBR, indicating it might be fairly valued.\n- The dividend yield is attractive for income-focused investors.\n- The consensus rating suggests a positive outlook with a target price higher than the current price.\n\nIf you need more detailed analysis or specific data, let me know!\nStep 4: Observed output of cmd `terminate` executed:\nThe interaction has been completed with status: success\n",
    'timestamp': '',
}
# Out:
# {'prompt': '삼성전자에 대해서 분석해줘',
# ...
